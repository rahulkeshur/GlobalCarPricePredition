# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## IMPORT DATA SET FOR BETTER UNDERSTANDING

# %%
GlobalCar_DataSet = pd.read_csv("global_cars_enhanced.csv")

# %%
GlobalCar_DataSet
# Out:
#        Car_ID     Brand  Manufacture_Year  Body_Type Fuel_Type Transmission  \
# 0    CAR_0001  Mercedes              2006        SUV    Petrol       Manual
# 1    CAR_0002    Nissan              2023      Coupe    Petrol    Automatic
# 2    CAR_0003    Nissan              2007  Hatchback    Diesel       Manual
# 3    CAR_0004    Nissan              2013      Coupe    Petrol       Manual
# 4    CAR_0005   Hyundai              2009  Hatchback    Hybrid    Automatic
# ..        ...       ...               ...        ...       ...          ...
# 295  CAR_0296      Audi              2015     Pickup    Hybrid    Automatic
# 296  CAR_0297      Ford              2023  Hatchback    Petrol       Manual
# 297  CAR_0298  Mercedes              2020        SUV  Electric    Automatic
# 298  CAR_0299      Ford              2023      Coupe    Diesel       Manual
# 299  CAR_0300       Kia              2023        SUV    Hybrid       Manual
#
# ...

# %%
GlobalCar_DataSet.keys()
# Out:
# Index(['Car_ID', 'Brand', 'Manufacture_Year', 'Body_Type', 'Fuel_Type',
#        'Transmission', 'Engine_CC', 'Horsepower', 'Mileage_km_per_l',
#        'Price_USD', 'Manufacturing_Country', 'Car_Age', 'Price_Category',
#        'HP_per_CC', 'Age_Category', 'Efficiency_Score'],
#       dtype='str')

# %%
GlobalCar_DataSet.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Car_ID                 300 non-null    str
#  1   Brand                  300 non-null    str
#  2   Manufacture_Year       300 non-null    int64
#  3   Body_Type              300 non-null    str
#  4   Fuel_Type              300 non-null    str
#  5   Transmission           300 non-null    str
#  6   Engine_CC              300 non-null    int64
#  7   Horsepower             300 non-null    int64
#  8   Mileage_km_per_l       300 non-null    int64
#  9   Price_USD              300 non-null    int64
#  10  Manufacturing_Country  300 non-null    str
#  11  Car_Age                300 non-null    int64
#  12  Price_Category         300 non-null    str
#  13  HP_per_CC              300 non-null    float64
#  14  Age_Category           300 non-null    str
# ...

# %%
GlobalCar_DataSet["Price_Category"].unique()
# Out:
# <StringArray>
# ['Premium', 'Mid-Range', 'Budget', 'Luxury']
# Length: 4, dtype: str

# %% [markdown]
# ## Preparing Data Set

# %%
GlobalCar_DataSet.describe()
# Out:
#        Manufacture_Year    Engine_CC  Horsepower  Mileage_km_per_l  \
# count        300.000000   300.000000  300.000000        300.000000
# mean        2015.123333  3052.880000  328.346667         19.716667
# std            5.966023  1117.937497  153.202644          6.028061
# min         2005.000000  1001.000000   70.000000         10.000000
# 25%         2010.000000  2074.000000  188.250000         15.000000
# 50%         2015.000000  3117.500000  329.500000         19.500000
# 75%         2020.000000  3964.000000  454.750000         24.000000
# max         2025.000000  4994.000000  599.000000         30.000000
#
#            Price_USD     Car_Age   HP_per_CC  Efficiency_Score
# count     300.000000  300.000000  300.000000        300.000000
# mean    60848.823333   10.876667    0.129559          0.485833
# std     34445.525598    5.966023    0.093239          0.301403
# min      5221.000000    1.000000    0.017800          0.000000
# ...

# %%
## Check the value are null or not
GlobalCar_DataSet.isnull()
# Out:
#      Car_ID  Brand  Manufacture_Year  Body_Type  Fuel_Type  Transmission  \
# 0     False  False             False      False      False         False
# 1     False  False             False      False      False         False
# 2     False  False             False      False      False         False
# 3     False  False             False      False      False         False
# 4     False  False             False      False      False         False
# ..      ...    ...               ...        ...        ...           ...
# 295   False  False             False      False      False         False
# 296   False  False             False      False      False         False
# 297   False  False             False      False      False         False
# 298   False  False             False      False      False         False
# 299   False  False             False      False      False         False
#
#      Engine_CC  Horsepower  Mileage_km_per_l  Price_USD  \
# ...

# %%
GlobalCar_DataSet.isnull().sum()
# Out:
# Car_ID                   0
# Brand                    0
# Manufacture_Year         0
# Body_Type                0
# Fuel_Type                0
# Transmission             0
# Engine_CC                0
# Horsepower               0
# Mileage_km_per_l         0
# Price_USD                0
# Manufacturing_Country    0
# Car_Age                  0
# Price_Category           0
# HP_per_CC                0
# Age_Category             0
# Efficiency_Score         0
# dtype: int64

# %%
GlobalCar_DataSet = GlobalCar_DataSet.reset_index()

# %%
del GlobalCar_DataSet["index"]

# %%
GlobalCar_DataSet["Car_ID"] = GlobalCar_DataSet["Car_ID"].str.replace("CAR_","").astype(int)

# %%
GlobalCar_DataSet.head()
# Out:
#    Car_ID     Brand  Manufacture_Year  Body_Type Fuel_Type Transmission  \
# 0       1  Mercedes              2006        SUV    Petrol       Manual
# 1       2    Nissan              2023      Coupe    Petrol    Automatic
# 2       3    Nissan              2007  Hatchback    Diesel       Manual
# 3       4    Nissan              2013      Coupe    Petrol       Manual
# 4       5   Hyundai              2009  Hatchback    Hybrid    Automatic
#
#    Engine_CC  Horsepower  Mileage_km_per_l  Price_USD Manufacturing_Country  \
# 0       4089         547                17      73407                   USA
# 1       4618         167                25      79370                   USA
# 2       1802         110                16      76549                 China
# 3       1835         373                16      48722                   USA
# 4       2332         145                28      83265                    UK
#
#    Car_Age Price_Category  HP_per_CC Age_Category  Efficiency_Score
# ...

# %%
## EDA - Exploratory Data Analysis
## Correlation
GlobalCar_DataSet.corr(numeric_only=True)
# Out:
#                     Car_ID  Manufacture_Year  Engine_CC  Horsepower  \
# Car_ID            1.000000          0.079154  -0.018996    0.009976
# Manufacture_Year  0.079154          1.000000   0.065402   -0.063101
# Engine_CC        -0.018996          0.065402   1.000000   -0.036996
# Horsepower        0.009976         -0.063101  -0.036996    1.000000
# Mileage_km_per_l -0.060713          0.000045   0.041585   -0.061263
# Price_USD         0.030847         -0.005602  -0.000749    0.104940
# Car_Age          -0.079154         -1.000000  -0.065402    0.063101
# HP_per_CC        -0.014644         -0.105807  -0.646685    0.659153
# Efficiency_Score -0.060713          0.000045   0.041585   -0.061263
#
#                   Mileage_km_per_l  Price_USD   Car_Age  HP_per_CC  \
# Car_ID                   -0.060713   0.030847 -0.079154  -0.014644
# Manufacture_Year          0.000045  -0.005602 -1.000000  -0.105807
# Engine_CC                 0.041585  -0.000749 -0.065402  -0.646685
# ...

# %%
# sns.pairplot(GlobalCar_DataSet)

# %%
plt.scatter(GlobalCar_DataSet["Price_USD"],GlobalCar_DataSet["Manufacture_Year"])
plt.xlabel("Price")
plt.ylabel("Age")
# Out:
# Text(0, 0.5, 'Age')

# %%
# sns.regplot(x="Brand", y="Price_USD", data = GlobalCar_DataSet)

# %%
# sns.regplot(x="Body_Type", y="Price_USD", data = GlobalCar_DataSet)

# %%
sns.regplot(x="Mileage_km_per_l", y="Price_USD", data = GlobalCar_DataSet)
# Out:
# <Axes: xlabel='Mileage_km_per_l', ylabel='Price_USD'>

# %%
X = GlobalCar_DataSet.drop("Price_USD", axis=1)
Y = GlobalCar_DataSet["Price_USD"]

# %%
## Drop the columns for better output
X = X.drop("Age_Category",axis=1)
X = X.drop("Car_ID",axis=1)

# %%
X.head()
# Out:
#       Brand  Manufacture_Year  Body_Type Fuel_Type Transmission  Engine_CC  \
# 0  Mercedes              2006        SUV    Petrol       Manual       4089
# 1    Nissan              2023      Coupe    Petrol    Automatic       4618
# 2    Nissan              2007  Hatchback    Diesel       Manual       1802
# 3    Nissan              2013      Coupe    Petrol       Manual       1835
# 4   Hyundai              2009  Hatchback    Hybrid    Automatic       2332
#
#    Horsepower  Mileage_km_per_l Manufacturing_Country  Car_Age Price_Category  \
# 0         547                17                   USA       20        Premium
# 1         167                25                   USA        3        Premium
# 2         110                16                 China       19        Premium
# 3         373                16                   USA       13      Mid-Range
# 4         145                28                    UK       17        Premium
#
#    HP_per_CC  Efficiency_Score
# ...

# %%
## Label encoding

# This method is not proper, so I changed it
from sklearn.preprocessing import LabelEncoder

##
# le = LabelEncoder()
# X["Brand"] = le.fit_transform(X["Brand"])
# X["Body_Type"] = le.fit_transform(X["Body_Type"])
# X["Fuel_Type"] = le.fit_transform(X["Fuel_Type"])
# X["Transmission"] = le.fit_transform(X["Transmission"])
# X["Manufacturing_Country"] = le.fit_transform(X["Manufacturing_Country"])
# X["Price_Category"] = le.fit_transform(X["Price_Category"])
# X["Age_Category"] = le.fit_transform(X["Age_Category"])
##

le_brand = LabelEncoder()
le_body = LabelEncoder()
le_fuel = LabelEncoder()
le_trans = LabelEncoder()
le_country = LabelEncoder()
le_price = LabelEncoder() 

X["Brand"] = le_brand.fit_transform(X["Brand"])
X["Body_Type"] = le_body.fit_transform(X["Body_Type"])
X["Fuel_Type"] = le_fuel.fit_transform(X["Fuel_Type"])
X["Transmission"] = le_trans.fit_transform(X["Transmission"])
X["Manufacturing_Country"] = le_country.fit_transform(X["Manufacturing_Country"])
X["Price_Category"] = le_price.fit_transform(X["Price_Category"])

# %%
X.head()
# Out:
#    Brand  Manufacture_Year  Body_Type  Fuel_Type  Transmission  Engine_CC  \
# 0      6              2006          3          3             1       4089
# 1      7              2023          0          3             0       4618
# 2      7              2007          1          0             1       1802
# 3      7              2013          0          3             1       1835
# 4      4              2009          1          2             0       2332
#
#    Horsepower  Mileage_km_per_l  Manufacturing_Country  Car_Age  \
# 0         547                17                      5       20
# 1         167                25                      5        3
# 2         110                16                      0       19
# 3         373                16                      5       13
# 4         145                28                      4       17
#
#    Price_Category  HP_per_CC  Efficiency_Score
# 0               3     0.1338              0.35
# ...

# %%
## train test split 
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,Y,test_size=0.3,random_state=41)

# %% [markdown]
# ## Import the model for train and test

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rendomForest = RandomForestRegressor()

# %%
rendomForest.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
rendom_pred = rendomForest.predict(X_test)

# %%
rendom_pred
# Out:
# array([ 71106.83,  46883.3 , 112360.46,  16567.64,  44375.88,  80132.32,
#        104748.47,  98363.12,  18902.93,  45024.84,  17625.1 ,  15063.12,
#         76334.63,  42103.99,  47745.43,  49247.01,  18243.06,  14753.61,
#        108218.13,  44213.69,  73706.8 ,  48755.55,  16517.23,  15049.04,
#         46947.01,  71646.57,  15762.62,  43551.04,  46298.96, 105501.52,
#         73852.9 ,  17565.45, 110190.92,  14475.38,  49766.56,  73460.54,
#         50519.92,  52223.59, 106387.69,  51127.73,  46737.68,  74238.39,
#         79629.07,  17037.21,  80441.16,  16605.04,  45292.39,  18601.34,
#         49554.2 , 104450.54, 110464.78,  18731.01,  46177.32,  43052.02,
#        102966.07, 108558.68,  49166.16,  19775.49,  74850.34,  73995.34,
#         44361.36, 112715.45,  13453.22,  50668.62,  16395.48,  18363.28,
#         78638.04,  19241.53,  44615.75, 105565.3 ,  82360.73,  73150.67,
#        107438.87,  78231.56,  45823.57, 107000.24,  13844.61,  46613.64,
# ...

# %%
plt.scatter(y_test,rendom_pred)

# %%
## residuals
residuals = y_test-rendom_pred

# %%
residuals
# Out:
# 197     3710.17
# 51     -5156.30
# 126     2664.54
# 259     5715.36
# 151    -7775.88
#          ...
# 40     -9564.69
# 220    -3592.40
# 150     5628.06
# 239   -10583.25
# 88    -11263.27
# Name: Price_USD, Length: 90, dtype: float64

# %%
sns.displot(residuals,kind = "kde")

# %% [markdown]
# ## Assumptions

# %%
## scatter plot with respect to prediction and residuals
plt.scatter(rendom_pred,residuals)

# %%
## calculation that helps to better vision of how the model trains

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

print(mean_absolute_error(y_test,rendom_pred))
print(mean_squared_error(y_test,rendom_pred))
print(np.sqrt(mean_squared_error(y_test, rendom_pred)))
# Out:
# 7015.011888888889
# 67510327.57230335
# 8216.466854573404

# %% [markdown]
# ## R square and adjusted R square

# %%
# Formula 
# R^2 = 1 - SSR/SST
# R^2 = coefficient of determination SSR = sum of squares of residuals SST = total sum of square

# %%
from sklearn.metrics import r2_score
score = r2_score(y_test,rendom_pred)
print(score)
# Out:
# 0.9421581917781858

# %%
# Adjusted R2 = 1 - [(1-R2)*(n-1)/(n-k-1)]

1 - (1-score)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)
# Out:
# 0.9322641982665597

# %% [markdown]
# ## New Data Prediction

# %%
# a method that helps to convert a string to an int

def prepare_input(input_data, X, encoders):
    result = []

    for col in X.columns:
        val = input_data[col]

        if col in encoders:  # categorical
            val = encoders[col].transform([val])[0]

        result.append(val)

    return result

# %%
encoders = {
    "Brand": le_brand,
    "Body_Type": le_body,
    "Fuel_Type": le_fuel,
    "Transmission": le_trans,
    "Manufacturing_Country": le_country,
    "Price_Category": le_price
    
}

user_input = {
    "Brand": "Mercedes",
    "Manufacture_Year": 2006,
    "Body_Type": "SUV",
    "Fuel_Type": "Petrol",
    "Transmission": "Manual",
    "Engine_CC":4089,
    "Horsepower": 547,
    "Mileage_km_per_l":17,
    "Manufacturing_Country": "USA",
    "Car_Age":20,
    "Price_Category": "Premium",
    "HP_per_CC": 0.1338,
    "Efficiency_Score": 0.35
}

data = prepare_input(user_input, X, encoders)
data = np.array(data).reshape(1,-1)
data
# Out:
# array([[6.000e+00, 2.006e+03, 3.000e+00, 3.000e+00, 1.000e+00, 4.089e+03,
#         5.470e+02, 1.700e+01, 5.000e+00, 2.000e+01, 3.000e+00, 1.338e-01,
#         3.500e-01]])

# %%
out = rendomForest.predict(data)
# Out:
# /home/rahul/Documents/AI ML/CAR_PRICE_PREDICTION/GlobalCarPricePredition/venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
out
# Out:
# array([75035.78])

# %%
GlobalCar_DataSet.iloc[0]
# Out:
# Car_ID                          1
# Brand                    Mercedes
# Manufacture_Year             2006
# Body_Type                     SUV
# Fuel_Type                  Petrol
# Transmission               Manual
# Engine_CC                    4089
# Horsepower                    547
# Mileage_km_per_l               17
# Price_USD                   73407
# Manufacturing_Country         USA
# Car_Age                        20
# Price_Category            Premium
# HP_per_CC                  0.1338
# Age_Category                  Old
# Efficiency_Score             0.35
# Name: 0, dtype: object

# %%
out
# Out:
# array([75035.78])

# %% [markdown]
# ### Pickling The Model file For Deployment

# %%
import pickle

# %%
pickle.dump(rendomForest,open('forestModel.pkl','wb'))
pickle.dump(encoders, open("encoders.pkl","wb"))
pickle.dump(list(X.columns), open("columns.pkl","wb"))

# %%
pickle_model = pickle.load(open('forestModel.pkl','rb'))

# %%
pickle_model.predict(data)
# Out:
# /home/rahul/venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([73970.36])
